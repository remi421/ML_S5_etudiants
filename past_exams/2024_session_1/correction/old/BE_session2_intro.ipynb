# %% [markdown]
# #Introduction:

# %% [markdown]
# Ce BE dure 3h environ. Il se termine à 16h55. L'énoncé est réparti dans deux notebooks différents. Les questions ne sont généralement pas bloquantes.
#
# Les parties 1 et 2 du problème touchent à des applications simples d'un FCN (UNet). L'exercice consiste en l'implmententation d'un transformer rudimentaire sur un problème de régression.
# A priori, le problème sera noté sur 12 pts et l' exercice sur 8 points.

# %% [markdown]
# **Pour démarrer:**

# %% [markdown]
# - Créer un dossier *session2_prenomNom* sur votre drive. Placez-y tous les énoncés et *utile_BE_session2.py*.
# - partager ce répertoire avec tpdeeplearning@gmail.com (droits d'**édition**, pour la correction).

# %% [markdown]
# **Pour terminer:**

# %% [markdown]
# - Fichier/Enregistrer le(s) notebook(s) en cours d'édition
# - Envoyer **tous vos notebooks** par mail à l'adresse tpdeeplearning@gmail.com en précisant vos **nom et prénom** dans le mail.

# %% [markdown]
# Bon courage !
